# %%
str1 = 'shaik'

# %%
print(str1)
# Out:
# shaik

# %%
name = input("Login : ")
# Out:
# Login :  Haseena

# %%
print(name)
# Out:
# Haseena

# %%
x = int(input('Enter number:'))
# Out:
# Enter number: 12

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(x - 10)
# Out:
# 2

# %%
fruit = 'banana'

# %%
print(len(fruit))
# Out:
# 6

# %%
print(fruit[2])
# Out:
# n

# %%
print(fruit[8-2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 print(fruit[8-2])
#
# IndexError: string index out of range

# %%
fruit = 'banana'
index = 2
while index < len(fruit) :  
     letter = fruit[index]  
     print(index, letter)
# Out:
# 2 n
# 3 a
# 4 n
# 5 a

# %%
fruit = 'banana'
print(fruit)
for i in fruit:
    print(i)
# Out:
# banana
# b
# a
# n
# a
# n
# a

# %%
fruit = 'haseena'
count = 0
for letter in fruit:
    if letter == 's':
        count = count + 1
    print(count)
# Out:
# 0
# 0
# 1
# 1
# 1
# 1
# 1

# %%
fruit = 'haseena'

# %%
fruit[0]
# Out:
# 'h'

# %%
fruit[0] = 'ha'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fruit[0] = 'ha'
#
# TypeError: 'str' object does not support item assignment

# %%
fruit = ['h','a','s','e','e','n','a']
'h' in fruit
fruit.sort(reverse = True)
fruit
# Out:
# ['s', 'n', 'h', 'e', 'e', 'a', 'a']

# %%
fruit[0] = 'ha'
fruit
# Out:
# ['ha', 'a', 's', 'e', 'e', 'n', 'a']

# %%
friends = [ 'Joseph', 'Glenn', 'Sally' ]
friends.sort(reverse = True)
friends
# Out:
# ['Sally', 'Joseph', 'Glenn']

# %%
nums = [3, 41, 12, 9, 74, 15]
sum(nums)
# min(nums)
# max(nums)
# sum(nums)/len(nums)
# len(nums)
# Out:
# 154

# %%
total = 0
for num in nums:
    total += num

# Print the sum of the numbers
print("The sum of the numbers is:", total)
# Out:
# The sum of the numbers is: 154

# %%
abc = 'Sahul; is; travelling; to ;chennai'
# x_abc = abc.replace('Sahul','Haseena')
# print(x_abc)
l_abc = abc.split(';')

l_abc
# Out:
# ['Sahul', ' is', ' travelling', ' to ', 'chennai']

# %%
statement = 'From shaul@gmail.com Sat Jan  5 09:14:16 2008'
sta = statement.split()
print(sta)
sta_1 = sta[1]
print(sta_1)
sta_2 = sta_1.split('@')
print(sta_2)
sta_2[1]
# Out:
# ['From', 'shaul@gmail.com', 'Sat', 'Jan', '5', '09:14:16', '2008']
# shaul@gmail.com
# ['shaul', 'gmail.com']
# 'gmail.com'

# %%
x = ('Glenn', 'Sally', 'Joseph')
x[0]
# Out:
# 'Glenn'

# %%
x.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 x.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
x[0] = 'Hari'
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 x[0] = 'Hari'
#       2 x
#
# TypeError: 'tuple' object does not support item assignment

# %%
num = (3, 41, 12, 9, 74, 15)
sum(num)
min(num)
max(num)
# Out:
# 74

# %%
l = ['count', 'index']
l = tuple()
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
(x, y) = (4, 'fred')
print(x)
print(y)
# Out:
# 4
# fred

# %%
d = dict()
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d['shannu'] = 'Chennai'
d['sahul'] = 'Nellore'
d['venkat'] = 'Bangalore'
print(d['sahul'])
# Out:
# Nellore

# %%
for (k,v) in d.items():  
        print(k, v)
# Out:
# shannu Kavali
# sahul Nellore
# venkat Bangalore

# %%
tups = d.items()
print(tups)
# Out:
# dict_items([('shannu', 'Kavali'), ('sahul', 'Nellore'), ('venkat', 'Bangalore')])

# %%
c = {'a':10, 'b':1, 'c':22}
c
# Out:
# {'a': 10, 'b': 1, 'c': 22}

# %%
tmp = list()

# %%
tmp
# Out:
# []

# %%
for k, v in c.items() :  
         tmp.append( (v, k) )
tmp
# Out:
# [(10, 'a'), (1, 'b'), (22, 'c')]

# %%
tmp.sort()
tmp
# Out:
# [(1, 'b'), (10, 'a'), (22, 'c')]
